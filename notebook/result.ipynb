# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO

# %%
import numpy as np

# %%
from IPython.display import Image

# %% [markdown]
# #model n

# %%
import pandas

# %%
model_1 = YOLO('/content/drive/MyDrive/result/runs(dataเก่า-model-n)/detect/train/weights/best.pt')

# %%
metrics1 = model_1.val(split = 'test')
# Out:
# Ultralytics YOLOv8.0.115  Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 17.0MB/s]
# val: Scanning /content/drive/MyDrive/data/data_yolov8/v1/test/labels.cache... 17 images, 0 backgrounds, 0 corrupt: 100%|██████████| 17/17 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
#                    all         17         87      0.847      0.814      0.884      0.517
#           not_triplets         17         22      0.833      0.679      0.792      0.455
#               triplets         17          5      0.726          1      0.928      0.747
#            with-helmet         17         28       0.95      0.682      0.901      0.488
#         without-helmet         17         32      0.878      0.896      0.913      0.377
# ...

# %%
model_2 = YOLO('/content/drive/MyDrive/result/runs(dataใหม่-model-n)/detect/train/weights/best.pt')

# %%
metrics = model_2.val(split = 'test' , conf = 0.2)
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 63.8MB/s]
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:14<00:00,  4.74s/it]
#                    all         42        179       0.64      0.695      0.719      0.446
#    not_ride_motorcycle         42         31        0.5      0.226      0.317      0.158
#           not_triplets         42         37       0.63      0.784      0.814      0.517
#               triplets         42          7      0.455      0.714      0.697      0.539
#            with-helmet         42         49      0.827      0.878      0.884      0.564
# ...

# %% [markdown]
# #model X

# %%
model_3 = YOLO('/content/drive/MyDrive/result/runs(dataเก่า-model-x)/detect/train/weights/best.pt')

# %%
metrics3 = model_3.val(split = 'test')
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68127420 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/data/testset/test/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:04<00:00,  1.55s/it]
#                    all         42        149      0.829      0.709      0.811      0.497
#           not_triplets         42         37      0.731      0.734      0.782      0.496
#               triplets         42          7      0.841      0.571       0.76        0.6
#            with-helmet         42         49       0.95      0.775      0.884      0.544
#         without-helmet         42         56      0.794      0.755      0.819      0.349
# Speed: 6.3ms preprocess, 51.5ms inference, 0.0ms loss, 8.2ms postprocess per image
# ...

# %%
model_4 = YOLO('/content/drive/MyDrive/result/runs(dataใหม่-model-x)/detect/train/weights/best.pt')

# %%
metrics4 = model_4.val(split = 'test')
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68128383 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:04<00:00,  1.61s/it]
#                    all         42        179      0.735      0.664      0.657       0.41
#    not_ride_motorcycle         42         31       0.76      0.258      0.335      0.204
#           not_triplets         42         37      0.743      0.625      0.679      0.402
#               triplets         42          7      0.541      0.844      0.568      0.473
#            with-helmet         42         49       0.85      0.816      0.904      0.572
#         without-helmet         42         55      0.781      0.777      0.796      0.399
# ...

# %%
Image('/content/runs/detect/val10/confusion_matrix_normalized.png' , width=800)

# %% [markdown]
# # Test : Conf 0.1 - 0.8

# %%
#0.1
metrics4 = model_4.val(split = 'test' , conf = 0.1)
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68128383 parameters, 0 gradients
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 46.7MB/s]
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:10<00:00,  3.41s/it]
#                    all         42        179      0.735      0.665      0.687      0.449
#    not_ride_motorcycle         42         31      0.759      0.258      0.485      0.317
#           not_triplets         42         37      0.744      0.628       0.66      0.415
#               triplets         42          7      0.542      0.847      0.591        0.5
#            with-helmet         42         49      0.851      0.816      0.885      0.584
# ...

# %%
Image('/content/runs/detect/val/confusion_matrix_normalized.png' , width=800)

# %%
#0.2
metrics4 = model_4.val(split = 'test' , conf = 0.2)
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68128383 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:04<00:00,  1.54s/it]
#                    all         42        179      0.745      0.669      0.697      0.464
#    not_ride_motorcycle         42         31        0.8      0.258      0.524      0.355
#           not_triplets         42         37       0.75      0.649      0.683      0.444
#               triplets         42          7      0.545      0.857      0.597      0.507
#            with-helmet         42         49      0.851      0.816      0.885      0.584
#         without-helmet         42         55      0.778      0.764      0.796      0.429
# ...

# %%
Image('/content/runs/detect/val2/confusion_matrix_normalized.png' , width=800)

# %%
#0.3
metrics4 = model_4.val(split = 'test' , conf = 0.3)
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:05<00:00,  1.69s/it]
#                    all         42        179      0.741      0.592      0.669      0.448
#    not_ride_motorcycle         42         31      0.778      0.226      0.503      0.357
#           not_triplets         42         37       0.76      0.601      0.676      0.449
#               triplets         42          7      0.472      0.571      0.491      0.426
#            with-helmet         42         49      0.897      0.796      0.878      0.582
#         without-helmet         42         55        0.8      0.764      0.796      0.429
# ...

# %%
Image('/content/runs/detect/val3/confusion_matrix_normalized.png' , width=800)

# %%
#0.4
metrics4 = model_4.val(split = 'test' , conf = 0.4)
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
#                    all         42        179       0.75       0.59       0.67      0.451
#    not_ride_motorcycle         42         31      0.778      0.226      0.503      0.357
#           not_triplets         42         37      0.759      0.595      0.664      0.441
#               triplets         42          7        0.5      0.571      0.503      0.437
#            with-helmet         42         49      0.907      0.796      0.882      0.586
#         without-helmet         42         55      0.808      0.764        0.8      0.432
# ...

# %%
Image('/content/runs/detect/val4/confusion_matrix_normalized.png' , width=800)

# %%
#0.5
metrics4 = model_4.val(split = 'test' , conf = 0.5)
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:04<00:00,  1.58s/it]
#                    all         42        179      0.795      0.547      0.671       0.46
#    not_ride_motorcycle         42         31      0.875      0.226      0.541      0.384
#           not_triplets         42         37      0.769      0.541      0.644      0.443
#               triplets         42          7        0.6      0.429      0.496      0.454
#            with-helmet         42         49      0.929      0.796      0.884      0.588
#         without-helmet         42         55      0.804      0.745      0.792       0.43
# ...

# %%
Image('/content/runs/detect/val5/confusion_matrix_normalized.png' , width=800)

# %%
#0.6
metrics4 = model_4.val(split = 'test' , conf = 0.6)
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:04<00:00,  1.37s/it]
#                    all         42        179      0.806      0.531      0.666      0.456
#    not_ride_motorcycle         42         31      0.875      0.226      0.541      0.384
#           not_triplets         42         37       0.76      0.514      0.631      0.433
#               triplets         42          7        0.6      0.429      0.496      0.454
#            with-helmet         42         49      0.951      0.796      0.886      0.591
#         without-helmet         42         55      0.844      0.691      0.775       0.42
# ...

# %%
Image('/content/runs/detect/val6/confusion_matrix_normalized.png' , width=800)

# %%
#0.7
metrics4 = model_4.val(split = 'test' , conf = 0.7)
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
#                    all         42        179       0.82       0.48      0.651      0.447
#    not_ride_motorcycle         42         31      0.857      0.194      0.517      0.368
#           not_triplets         42         37      0.792      0.514      0.639      0.439
#               triplets         42          7      0.667      0.286      0.477      0.439
#            with-helmet         42         49      0.949      0.755      0.867       0.58
#         without-helmet         42         55      0.837      0.655      0.758       0.41
# ...

# %%
Image('/content/runs/detect/val7/confusion_matrix_normalized.png' , width=800)

# %%
#0.8
metrics4 = model_4.val(split = 'test' , conf = 0.8)
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:04<00:00,  1.40s/it]
#                    all         42        179      0.829      0.439      0.633       0.44
#    not_ride_motorcycle         42         31      0.833      0.161       0.49       0.35
#           not_triplets         42         37      0.818      0.486      0.632      0.435
#               triplets         42          7      0.667      0.286      0.477      0.439
#            with-helmet         42         49      0.946      0.714      0.847      0.569
#         without-helmet         42         55      0.882      0.545      0.719      0.405
# ...

# %%
Image('/content/runs/detect/val8/confusion_matrix_normalized.png' , width=800)

# %%
metrics4 = model_4.val(split = 'test' ,half = True)
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/MyDrive/data/testset/test5class/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:03<00:00,  1.19s/it]
#                    all         42        179      0.735      0.663      0.657      0.408
#    not_ride_motorcycle         42         31      0.761      0.258      0.335      0.203
#           not_triplets         42         37      0.742      0.622      0.678      0.401
#               triplets         42          7      0.541      0.843      0.568      0.473
#            with-helmet         42         49       0.85      0.816      0.905       0.57
#         without-helmet         42         55      0.781      0.777      0.796      0.395
# ...

# %%
Image('/content/runs/detect/val9/confusion_matrix_normalized.png' , width=800)

# %% [markdown]
# ## ทดลองใช้model

# %%
result = model_4('/content/drive/MyDrive/สไตล์การขับขี่มอเตอร์ไซค์บอกนิสัยคุณได้-02.jpg')
# Out:
# image 1/1 /content/drive/MyDrive/สไตล์การขับขี่มอเตอร์ไซค์บอกนิสัยคุณได้-02.jpg: 416x640 1 not_triplets, 67.1ms
# Speed: 12.7ms preprocess, 67.1ms inference, 38.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
results =  model_4('/content/drive/MyDrive/5 เคล็ดลับซ้อนท้ายมอเตอร์ไซค์ - ข้อมูลความรู้ - 2021 6.jpg' , conf = 0.2)
# Out:
# image 1/1 /content/drive/MyDrive/5 เคล็ดลับซ้อนท้ายมอเตอร์ไซค์ - ข้อมูลความรู้ - 2021 6.jpg: 448x640 1 not_triplets, 2 with-helmets, 76.6ms
# Speed: 2.5ms preprocess, 76.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
boxes = results[0].boxes
box = boxes[0]
box.xyxy
# Out:
# tensor([[427.1978,  86.1679, 522.2109, 216.5031]], device='cuda:0')

# %%
print(boxes.cls.values)
# Out:
# <built-in method values of Tensor object at 0x7fb3f08b1210>

# %%
print(boxes.cls)
# Out:
# tensor([3., 1., 3.], device='cuda:0')

# %%
x = boxes.cls

# %%
x[0].item()
# Out:
# 3.0

# %%
x.cpu().numpy()
# Out:
# array([          3,           1,           3], dtype=float32)

# %%
detection_cls = x.cpu().numpy().tolist()
cls = {
0: 'not_ride_motorcycle',
1: "not_triplets",
2: "triplets",
3: 'with-helmet',
4: 'without-helmet'
}
detection_cls = [cls[x] for x in detection_cls]

# %%
print(detection_cls)
# Out:
# ['with-helmet', 'not_triplets', 'with-helmet']
